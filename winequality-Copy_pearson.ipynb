# %%
import numpy as np
import pandas as pd

# %% [markdown]
# reading the data set

# %%
df=pd.read_csv('WineQT.csv')
df
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [markdown]
# dropping the unwanted Id column

# %%
df.drop(columns=['Id'])
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [raw]
# checking the dataset columns, their datatypes and any null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
df.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %% [markdown]
# performing the actions in the column names

# %%
#performing the column data
df.columns=df.columns.str.replace(' ','_')

# %%
df.head()
# Out:
#    fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free_sulfur_dioxide  total_sulfur_dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %% [markdown]
# importing the visualisation libraries

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.distplot(df['volatile_acidity'])
# Out:
# C:\Users\madhu\AppData\Local\Temp\ipykernel_18700\2726508207.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['volatile_acidity'])
# <Axes: xlabel='volatile_acidity', ylabel='Density'>

# %%
len(df.columns)
# Out:
# 13

# %%
df.columns
# Out:
# Index(['fixed_acidity', 'volatile_acidity', 'citric_acid', 'residual_sugar',
#        'chlorides', 'free_sulfur_dioxide', 'total_sulfur_dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality', 'Id'],
#       dtype='object')

# %% [markdown]
# importing the sklearn library to perform the feature selection operation

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import f_regression,SelectKBest

# %%
x=df.iloc[:,:-1]
y=df['quality']
x
# Out:
#       fixed_acidity  volatile_acidity  citric_acid  residual_sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1138            6.3             0.510         0.13             2.3      0.076
# 1139            6.8             0.620         0.08             1.9      0.068
# 1140            6.2             0.600         0.08             2.0      0.090
# 1141            5.9             0.550         0.10             2.2      0.062
# 1142            5.9             0.645         0.12             2.0      0.075
#
# ...

# %% [markdown]
# performing the feature selection using the f_regression with select k best method
# visit the website for more info
# f_regression- https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.f_regression.html
# selectKBest - https://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.SelectKBest.html

# %%
def feature_selection(x_train,x_test,y_train):
    fs=SelectKBest(score_func=f_regression,k=4)
    fs.fit(x_train,y_train)
    
    return fs

# %% [markdown]
# selecting the top 4 columns which shows more impact on the quality of wine according to their scores

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y)
fs=feature_selection(x_train,x_test,y_train)
for i in range(len(fs.scores_)):
    print('Feature %d: %f %s' % (i, fs.scores_[i],df.columns[i]))
# Out:
# Feature 0: 8.754095 fixed_acidity
# Feature 1: 179.540822 volatile_acidity
# Feature 2: 47.457734 citric_acid
# Feature 3: 0.346023 residual_sugar
# Feature 4: 11.735048 chlorides
# Feature 5: 5.895933 free_sulfur_dioxide
# Feature 6: 44.821287 total_sulfur_dioxide
# Feature 7: 38.590730 density
# Feature 8: 1.590201 pH
# Feature 9: 48.184078 sulphates
# Feature 10: 273.834990 alcohol
# Feature 11: -137520631478635632.000000 quality

# %% [markdown]
# plotting the data of the selected columns to see their relation ship type with the dependent column

# %%
fig,axes=plt.subplots(4,1,figsize=(15,10))

axes[0].plot(df.index,df['quality'],df['alcohol'])
plt.xlabel('quality')
axes[1].plot(df.index,df['quality'],df['volatile_acidity'])
axes[2].plot(df.index,df['quality'],df['sulphates'])
axes[3].plot(df.index,df['quality'],df['citric_acid'])

# %% [markdown]
# creating the new dataframe with selected 4 columns

# %%
new_df=df[['alcohol','volatile_acidity','sulphates','citric_acid','quality']]

# %%
fig,axes=plt.subplots(2,2,figsize=(12,10))

axes[0,0].boxplot(df['alcohol'])
axes[0,1].boxplot(df['volatile_acidity'])
axes[1,0].boxplot(df['sulphates'])
axes[1,1].boxplot(df['citric_acid'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x268d6d3d490>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x268d6d3e6d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x268d6d28d90>],
#  'medians': [<matplotlib.lines.Line2D at 0x268d6d3f850>],
#  'fliers': [<matplotlib.lines.Line2D at 0x268d6d4c050>],
#  'means': []}

# %% [markdown]
# removing the outliers in the dataset with percentile method

# %%
Q1 = new_df.iloc[:,:-1].quantile(0.25)
Q3 = new_df.iloc[:,:-1].quantile(0.75)
IQR = Q3 - Q1

new_df = new_df[~((new_df.iloc[:,:-1] < (Q1 - 1.5 * IQR)) |(new_df.iloc[:,:-1] > (Q3 + 1.5 * IQR))).any(axis=1)]

# %% [markdown]
# checking the outliers with the boxplot visualisation

# %%
pd.unique(new_df['quality'])
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
new_df
# Out:
#       alcohol  volatile_acidity  sulphates  citric_acid  quality
# 0         9.4             0.700       0.56         0.00        5
# 1         9.8             0.880       0.68         0.00        5
# 2         9.8             0.760       0.65         0.04        5
# 3         9.8             0.280       0.58         0.56        6
# 4         9.4             0.700       0.56         0.00        5
# ...       ...               ...        ...          ...      ...
# 1138     11.0             0.510       0.75         0.13        6
# 1139      9.5             0.620       0.82         0.08        6
# 1140     10.5             0.600       0.58         0.08        5
# 1141     11.2             0.550       0.76         0.10        6
# 1142     10.2             0.645       0.71         0.12        5
#
# [1074 rows x 5 columns]

# %%
plt.figure(figsize=(12,5))

sns.heatmap(new_df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import MinMaxScaler

# %%
from sklearn.model_selection import train_test_split

# %%
scaler=MinMaxScaler()
new_df['alcohol']=scaler.fit_transform(new_df[['alcohol']])

# %%
new_df
# Out:
#       alcohol  volatile_acidity  sulphates  citric_acid  quality
# 0        0.20             0.700       0.56         0.00        5
# 1        0.28             0.880       0.68         0.00        5
# 2        0.28             0.760       0.65         0.04        5
# 3        0.28             0.280       0.58         0.56        6
# 4        0.20             0.700       0.56         0.00        5
# ...       ...               ...        ...          ...      ...
# 1138     0.52             0.510       0.75         0.13        6
# 1139     0.22             0.620       0.82         0.08        6
# 1140     0.42             0.600       0.58         0.08        5
# 1141     0.56             0.550       0.76         0.10        6
# 1142     0.36             0.645       0.71         0.12        5
#
# [1074 rows x 5 columns]

# %%
indexes=list(np.where(new_df['quality']==1))
print(len(indexes[0]))
# Out:
# 0

# %%
x=new_df.iloc[:,:-1]
y=new_df['quality']
y
# Out:
# 0       5
# 1       5
# 2       5
# 3       6
# 4       5
#        ..
# 1138    6
# 1139    6
# 1140    5
# 1141    6
# 1142    5
# Name: quality, Length: 1074, dtype: int64

# %%
x
# Out:
#       alcohol  volatile_acidity  sulphates  citric_acid
# 0        0.20             0.700       0.56         0.00
# 1        0.28             0.880       0.68         0.00
# 2        0.28             0.760       0.65         0.04
# 3        0.28             0.280       0.58         0.56
# 4        0.20             0.700       0.56         0.00
# ...       ...               ...        ...          ...
# 1138     0.52             0.510       0.75         0.13
# 1139     0.22             0.620       0.82         0.08
# 1140     0.42             0.600       0.58         0.08
# 1141     0.56             0.550       0.76         0.10
# 1142     0.36             0.645       0.71         0.12
#
# [1074 rows x 4 columns]

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(x_train,y_train)
y_predict=model.predict(x_test)
# Out:
# F:\files\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_predict,y_test)
# Out:
# 0.8601398601398601

# %%
from sklearn.tree import DecisionTreeClassifier
model=DecisionTreeClassifier()
model.fit(x_train,y_train)
y_predict=model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(y_predict,y_test)
# Out:
# 1.0
